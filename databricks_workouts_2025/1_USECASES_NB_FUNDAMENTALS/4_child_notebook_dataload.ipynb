# %%
import requests
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
sample_data = requests.get(url)
csv_data = sample_data.text
dbutils.fs.put("/Volumes/workspace/default/volumewd36_datalake/usage_metrics/mobile_os_usage.csv", csv_data, overwrite=True)
