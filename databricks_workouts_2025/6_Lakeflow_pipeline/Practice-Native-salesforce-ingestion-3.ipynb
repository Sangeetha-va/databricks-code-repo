# %%
# %sql
--1.Create a salesforce account
--2.In databricks create a new conection from unity catalog
--3.go to data ingestion, select sales force and follow the steps
--4.save and run the pipeline
--5.write query here to check the data

select * from lakeflow_pl_cat.lakeflow_pl_sch.account;
